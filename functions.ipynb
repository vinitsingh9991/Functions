# %% [markdown]
# #Functions

# %% [markdown]
# 1. what is the difference between a function and a method in python ?
#    - a functions is independent and can be called from anywhere
# 2. second question
#    - the is for senond question answer
